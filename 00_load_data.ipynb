# %% [markdown]
# # Load data
#
# arXiv.org submitters. (2024). arXiv Dataset [Data set]. Kaggle. https://doi.org/10.34740/KAGGLE/DSV/7548853
#
# * Download the data manually, put it in folder `data`.
# * Load all the data into a dataframe

# %%
import pandas as pd
import json

frames = []
max_bytes = 1024 * 100  # max bytes to read from file
# one json per line
with open('arxiv-metadata-oai-snapshot.json') as json_file:    
    lines = json_file.readlines(max_bytes)
    for line in lines:
        data = json.loads(line)
        frames.append(pd.json_normalize(data))
arxiv_df = pd.concat(frames)

# %%
arxiv_df.head()
# Out:
#           id           submitter  \
# 0  0704.0001      Pavel Nadolsky
# 0  0704.0002        Louis Theran
# 0  0704.0003         Hongjun Pan
# 0  0704.0004        David Callan
# 0  0704.0005  Alberto Torchinsky
#
#                                              authors  \
# 0  C. Bal\'azs, E. L. Berger, P. M. Nadolsky, C.-...
# 0                    Ileana Streinu and Louis Theran
# 0                                        Hongjun Pan
# 0                                       David Callan
# 0           Wael Abu-Shammala and Alberto Torchinsky
#
#                                                title  \
# 0  Calculation of prompt diphoton production cros...
# 0           Sparsity-certifying Graph Decompositions
# 0  The evolution of the Earth-Moon system based o...
# 0  A determinant of Stirling cycle numbers counts...
# 0  From dyadic $\Lambda_{\alpha}$ to $\Lambda_{\a...
#
#                                   comments  \
# 0  37 pages, 15 figures; published version
# 0    To appear in Graphs and Combinatorics
# 0                      23 pages, 3 figures
# 0                                 11 pages
# 0                                     None
#
#                                  journal-ref                         doi  \
# 0                   Phys.Rev.D76:013009,2007  10.1103/PhysRevD.76.013009
# 0                                       None                        None
# 0                                       None                        None
# 0                                       None                        None
# 0  Illinois J. Math. 52 (2008) no.2, 681-689                        None
#
#           report-no       categories  \
# 0  ANL-HEP-PR-07-12           hep-ph
# 0              None    math.CO cs.CG
# 0              None   physics.gen-ph
# 0              None          math.CO
# 0              None  math.CA math.FA
#
#                                              license  \
# 0                                               None
# 0  http://arxiv.org/licenses/nonexclusive-distrib...
# 0                                               None
# 0                                               None
# 0                                               None
#
#                                             abstract  \
# 0    A fully differential calculation in perturba...
# 0    We describe a new algorithm, the $(k,\ell)$-...
# 0    The evolution of Earth-Moon system is descri...
# 0    We show that a determinant of Stirling cycle...
# 0    In this paper we show how to compute the $\L...
#
#                                             versions update_date  \
# 0  [{'version': 'v1', 'created': 'Mon, 2 Apr 2007...  2008-11-26
# 0  [{'version': 'v1', 'created': 'Sat, 31 Mar 200...  2008-12-13
# 0  [{'version': 'v1', 'created': 'Sun, 1 Apr 2007...  2008-01-13
# 0  [{'version': 'v1', 'created': 'Sat, 31 Mar 200...  2007-05-23
# 0  [{'version': 'v1', 'created': 'Mon, 2 Apr 2007...  2013-10-15
#
#                                       authors_parsed
# 0  [[Balázs, C., ], [Berger, E. L., ], [Nadolsky,...
# 0           [[Streinu, Ileana, ], [Theran, Louis, ]]
# 0                                 [[Pan, Hongjun, ]]
# 0                                [[Callan, David, ]]
# 0  [[Abu-Shammala, Wael, ], [Torchinsky, Alberto, ]]

# %% [markdown]
# ## Keep only published papers
# * Keep paper only if journal-ref is not None
# * save compressed csv

# %%
total = arxiv_df.shape[0]
idx = arxiv_df['journal-ref'].isna()
arxiv_df = arxiv_df[~idx]
print(f"The cleaned up data has {arxiv_df.shape[0]} entries. {total - arxiv_df.shape[0]} entries were discarded.")
# Out:
# The cleaned up data has 39 entries. 30 entries were discarded.

# %%
import zipfile as zf

with zf.ZipFile('data/arxiv.zip', 'w') as ziparchive:
    ziparchive.writestr('arxiv.csv', arxiv_df.to_csv())
