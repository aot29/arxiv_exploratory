# %% [markdown]
# # Save topic model as an ontology
# * Open the trained model
# * Create necessary classes and properties
#
# see: https://owlready2.readthedocs.io/en/latest/index.html

# %%
import pickle
from owlready2 import *

# %% [markdown]
# ## Load the trained model
# The model was trained in notebook 01_Train_model

# %%
with open('../models/lda_nlp_train.pickle', 'rb') as handle:
    ldamodel = pickle.load(handle)

# %% [markdown]
# ## Load the trained submodels
# These models have been trained on each topic.

# %%
with open('../models/topic_model.pickle', 'rb') as handle:
    ldasubmodel = pickle.load(handle)

# %% [markdown]
# ## Convert topics to OWL classes

# %%
import random

# get all topics in the model
topics = ldamodel.show_topics(formatted=False)

# create a new empty ontology
iri = "http://fan.zib.de/aot29/topic_"
ontology = get_ontology(f"{iri}_{random.randint(1,1000000)}.owl")

#################
#   datatypes   #
#################

class WordProbability:
    def __init__(self, word, probability):
        self.word = word
        self.probability = probability

def wp_parser(s):
    splits = s.split(',')
    word = splits[0].strip()
    probability = float(splits[1].strip())
    return(WordProbability(word, probability))
    
def wp_unparser(x):
    return (f"('{x.word}', {x.probability})")    

declare_datatype(WordProbability, f"{iri}#WordProbability", wp_parser, wp_unparser)

def label_clean(topic):
    resp = str([topic[1][i][0] for i in range(0, 3)]).replace('[','').replace(']','').replace('\'','')
#    print(resp)
    return resp

with ontology:

    #################
    #    classes    #
    #################
    
    class Topic(Thing):
        pass

    class has_parent(ObjectProperty):
        domain = [Topic]
        range = [Topic]

    class topic_id(DataProperty, FunctionalProperty):
        domain = [Topic]
        range = [int]

    class label(DataProperty, FunctionalProperty):
        domain = [Topic]
        range = [str]

    class word_probabilities(DataProperty):
        domain = [Topic]
        range = [WordProbability]
    
    #################
    #   instances   #
    #################
    
    # the base topic instance for all topics is NLP
    base_topic = Topic("NLP")
    
    for topic in topics:
        topic_id = topic[0]
        label = label_clean(topic)  # use the first 3 words as the label
        word_probabilities = str(topic[1])
        name = f"{topic_id}: {label}"
        new_topic = Topic(name, has_parent=[base_topic], topic_id=topic_id, label=label, word_probabilities=[word_probabilities])
        # subtopics
        submodel = ldasubmodel[topic_id]
        print(f"{topic_id}: {submodel}")
        subtopics = submodel.show_topics(formatted=False)
        for subtopic in subtopics:
            subtopic_id = f"{topic_id}.{subtopic[0]}"
#            print(subtopic_id)
#            print(sub_name)
            sub_label = label_clean(subtopic)  # use the first 3 words as the label
#            print(sub_label)
            word_probabilities = str(subtopic[1])
#            print(word_probabilities)
            sub_name = f"{topic_id}.{subtopic[0]}: {sub_label}"
            new_subtopic = Topic(sub_name, has_parent=[new_topic], topic_id=subtopic_id, label=sub_label, word_probabilities=[word_probabilities])
# Out:
# 0: LdaModel<num_terms=3011, num_topics=5, decay=0.5, chunksize=2000>
# 1: LdaModel<num_terms=3146, num_topics=7, decay=0.5, chunksize=2000>
# 2: LdaModel<num_terms=2299, num_topics=9, decay=0.5, chunksize=2000>
# 3: LdaModel<num_terms=2378, num_topics=10, decay=0.5, chunksize=2000>
# 4: LdaModel<num_terms=2395, num_topics=11, decay=0.5, chunksize=2000>
# 5: LdaModel<num_terms=2381, num_topics=5, decay=0.5, chunksize=2000>
# 6: LdaModel<num_terms=3064, num_topics=13, decay=0.5, chunksize=2000>
# 7: LdaModel<num_terms=2918, num_topics=8, decay=0.5, chunksize=2000>

# %%
ontology.save(file='../data/topics.owl', format='rdfxml')

# %%
import rdflib
import networkx as nx
import matplotlib.pyplot as plt
from networkx.drawing.nx_agraph import graphviz_layout
from networkx.drawing.nx_pydot import pydot_layout
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[74], line 6
#       4 from networkx.drawing.nx_agraph import graphviz_layout
#       5 from networkx.drawing.nx_pydot import pydot_layout
# ----> 6 import pydot
#
# ModuleNotFoundError: No module named 'pydot'

# %%
# Load the OWL file
g = rdflib.Graph()
g.parse("../data/topics.owl", format="xml")
# Out:
# http://fan.zib.de/aot29/topic__118999.owl#0: word, embed, semant does not look like a valid URI, trying to serialize this will break.
# http://fan.zib.de/aot29/topic__118999.owl#0.0: word, embed, represent does not look like a valid URI, trying to serialize this will break.
# http://fan.zib.de/aot29/topic__118999.owl#0: word, embed, semant does not look like a valid URI, trying to serialize this will break.
# http://fan.zib.de/aot29/topic__118999.owl#0.1: semant, structur, process does not look like a valid URI, trying to serialize this will break.
# http://fan.zib.de/aot29/topic__118999.owl#0: word, embed, semant does not look like a valid URI, trying to serialize this will break.
# http://fan.zib.de/aot29/topic__118999.owl#0.2: concept, topic, semant does not look like a valid URI, trying to serialize this will break.
# http://fan.zib.de/aot29/topic__118999.owl#0: word, embed, semant does not look like a valid URI, trying to serialize this will break.
# http://fan.zib.de/aot29/topic__118999.owl#0.3: word, text, base does not look like a valid URI, trying to serialize this will break.
# http://fan.zib.de/aot29/topic__118999.owl#0: word, embed, semant does not look like a valid URI, trying to serialize this will break.
# http://fan.zib.de/aot29/topic__118999.owl#0.4: gener, base, pars does not look like a valid URI, trying to serialize this will break.
# http://fan.zib.de/aot29/topic__118999.owl#0: word, embed, semant does not look like a valid URI, trying to serialize this will break.
# http://fan.zib.de/aot29/topic__118999.owl#1: gener, question, llm does not look like a valid URI, trying to serialize this will break.
# http://fan.zib.de/aot29/topic__118999.owl#1.0: llm, larg, prompt does not look like a valid URI, trying to serialize this will break.
# http://fan.zib.de/aot29/topic__118999.owl#1: gener, question, llm does not look like a valid URI, trying to serialize this will break.
# http://fan.zib.de/aot29/topic__118999.owl#1.1: code, learn, problem does not look like a valid URI, trying to serialize this will break.
# http://fan.zib.de/aot29/topic__118999.owl#1: gener, question, llm does not look like a valid URI, trying to serialize this will break.
# http://fan.zib.de/aot29/topic__118999.owl#1.2: explan, human, predict does not look like a valid URI, trying to serialize this will break.
# http://fan.zib.de/aot29/topic__118999.owl#1: gener, question, llm does not look like a valid URI, trying to serialize this will break.
# http://fan.zib.de/aot29/topic__118999.owl#1.3: text, video, sentenc does not look like a valid URI, trying to serialize this will break.
# http://fan.zib.de/aot29/topic__118999.owl#1: gener, question, llm does not look like a valid URI, trying to serialize this will break.
# http://fan.zib.de/aot29/topic__118999.owl#1.4: evalu, metric, human does not look like a valid URI, trying to serialize this will break.
# http://fan.zib.de/aot29/topic__118999.owl#1: gener, question, llm does not look like a valid URI, trying to serialize this will break.
# http://fan.zib.de/aot29/topic__118999.owl#1.5: imag, visual, caption does not look like a valid URI, trying to serialize this will break.
# http://fan.zib.de/aot29/topic__118999.owl#1: gener, question, llm does not look like a valid URI, trying to serialize this will break.
# http://fan.zib.de/aot29/topic__118999.owl#1.6: question, answer, knowledg does not look like a valid URI, trying to serialize this will break.
# http://fan.zib.de/aot29/topic__118999.owl#1: gener, question, llm does not look like a valid URI, trying to serialize this will break.
# http://fan.zib.de/aot29/topic__118999.owl#2: data, train, learn does not look like a valid URI, trying to serialize this will break.
# http://fan.zib.de/aot29/topic__118999.owl#2.0: cross, entiti, lingual does not look like a valid URI, trying to serialize this will break.
# http://fan.zib.de/aot29/topic__118999.owl#2: data, train, learn does not look like a valid URI, trying to serialize this will break.
# http://fan.zib.de/aot29/topic__118999.owl#2.1: resourc, translat, multilingu does not look like a valid URI, trying to serialize this will break.
# http://fan.zib.de/aot29/topic__118999.owl#2: data, train, learn does not look like a valid URI, trying to serialize this will break.
# http://fan.zib.de/aot29/topic__118999.owl#2.2: text, style, transfer does not look like a valid URI, trying to serialize this will break.
# http://fan.zib.de/aot29/topic__118999.owl#2: data, train, learn does not look like a valid URI, trying to serialize this will break.
# http://fan.zib.de/aot29/topic__118999.owl#2.3: adversari, attack, exampl does not look like a valid URI, trying to serialize this will break.
# http://fan.zib.de/aot29/topic__118999.owl#2: data, train, learn does not look like a valid URI, trying to serialize this will break.
# http://fan.zib.de/aot29/topic__118999.owl#2.4: sentenc, label, gener does not look like a valid URI, trying to serialize this will break.
# http://fan.zib.de/aot29/topic__118999.owl#2: data, train, learn does not look like a valid URI, trying to serialize this will break.
# http://fan.zib.de/aot29/topic__118999.owl#2.5: gener, distribut, predict does not look like a valid URI, trying to serialize this will break.
# http://fan.zib.de/aot29/topic__118999.owl#2: data, train, learn does not look like a valid URI, trying to serialize this will break.
# http://fan.zib.de/aot29/topic__118999.owl#2.6: shot, dataset, zero does not look like a valid URI, trying to serialize this will break.
# http://fan.zib.de/aot29/topic__118999.owl#2: data, train, learn does not look like a valid URI, trying to serialize this will break.
# http://fan.zib.de/aot29/topic__118999.owl#2.7: label, classif, supervis does not look like a valid URI, trying to serialize this will break.
# http://fan.zib.de/aot29/topic__118999.owl#2: data, train, learn does not look like a valid URI, trying to serialize this will break.
# http://fan.zib.de/aot29/topic__118999.owl#2.8: domain, adapt, detect does not look like a valid URI, trying to serialize this will break.
# http://fan.zib.de/aot29/topic__118999.owl#2: data, train, learn does not look like a valid URI, trying to serialize this will break.
# http://fan.zib.de/aot29/topic__118999.owl#3: inform, entiti, extract does not look like a valid URI, trying to serialize this will break.
# http://fan.zib.de/aot29/topic__118999.owl#3.0: entiti, inform, relat does not look like a valid URI, trying to serialize this will break.
# http://fan.zib.de/aot29/topic__118999.owl#3: inform, entiti, extract does not look like a valid URI, trying to serialize this will break.
# http://fan.zib.de/aot29/topic__118999.owl#3.1: knowledg, graph, dialogu does not look like a valid URI, trying to serialize this will break.
# http://fan.zib.de/aot29/topic__118999.owl#3: inform, entiti, extract does not look like a valid URI, trying to serialize this will break.
# http://fan.zib.de/aot29/topic__118999.owl#3.2: graph, text, inform does not look like a valid URI, trying to serialize this will break.
# http://fan.zib.de/aot29/topic__118999.owl#3: inform, entiti, extract does not look like a valid URI, trying to serialize this will break.
# http://fan.zib.de/aot29/topic__118999.owl#3.3: document, queri, summar does not look like a valid URI, trying to serialize this will break.
# http://fan.zib.de/aot29/topic__118999.owl#3: inform, entiti, extract does not look like a valid URI, trying to serialize this will break.
# http://fan.zib.de/aot29/topic__118999.owl#3.4: clinic, medic, data does not look like a valid URI, trying to serialize this will break.
# http://fan.zib.de/aot29/topic__118999.owl#3: inform, entiti, extract does not look like a valid URI, trying to serialize this will break.
# http://fan.zib.de/aot29/topic__118999.owl#3.5: label, text, classif does not look like a valid URI, trying to serialize this will break.
# http://fan.zib.de/aot29/topic__118999.owl#3: inform, entiti, extract does not look like a valid URI, trying to serialize this will break.
# http://fan.zib.de/aot29/topic__118999.owl#3.6: event, aspect, extract does not look like a valid URI, trying to serialize this will break.
# http://fan.zib.de/aot29/topic__118999.owl#3: inform, entiti, extract does not look like a valid URI, trying to serialize this will break.
# http://fan.zib.de/aot29/topic__118999.owl#3.7: relat, extract, report does not look like a valid URI, trying to serialize this will break.
# http://fan.zib.de/aot29/topic__118999.owl#3: inform, entiti, extract does not look like a valid URI, trying to serialize this will break.
# http://fan.zib.de/aot29/topic__118999.owl#3.8: code, corefer, match does not look like a valid URI, trying to serialize this will break.
# http://fan.zib.de/aot29/topic__118999.owl#3: inform, entiti, extract does not look like a valid URI, trying to serialize this will break.
# http://fan.zib.de/aot29/topic__118999.owl#3.9: network, neural, attent does not look like a valid URI, trying to serialize this will break.
# http://fan.zib.de/aot29/topic__118999.owl#3: inform, entiti, extract does not look like a valid URI, trying to serialize this will break.
# http://fan.zib.de/aot29/topic__118999.owl#4: translat, speech, neural does not look like a valid URI, trying to serialize this will break.
# http://fan.zib.de/aot29/topic__118999.owl#4.10: network, neural, layer does not look like a valid URI, trying to serialize this will break.
# http://fan.zib.de/aot29/topic__118999.owl#4: translat, speech, neural does not look like a valid URI, trying to serialize this will break.
# http://fan.zib.de/aot29/topic__118999.owl#4.2: gener, text, tt does not look like a valid URI, trying to serialize this will break.
# http://fan.zib.de/aot29/topic__118999.owl#4: translat, speech, neural does not look like a valid URI, trying to serialize this will break.
# http://fan.zib.de/aot29/topic__118999.owl#4.3: data, recognit, represent does not look like a valid URI, trying to serialize this will break.
# http://fan.zib.de/aot29/topic__118999.owl#4: translat, speech, neural does not look like a valid URI, trying to serialize this will break.
# http://fan.zib.de/aot29/topic__118999.owl#4.9: end, neural, network does not look like a valid URI, trying to serialize this will break.
# http://fan.zib.de/aot29/topic__118999.owl#4: translat, speech, neural does not look like a valid URI, trying to serialize this will break.
# http://fan.zib.de/aot29/topic__118999.owl#4.1: decod, sequenc, encod does not look like a valid URI, trying to serialize this will break.
# http://fan.zib.de/aot29/topic__118999.owl#4: translat, speech, neural does not look like a valid URI, trying to serialize this will break.
# http://fan.zib.de/aot29/topic__118999.owl#4.0: speaker, voic, audio does not look like a valid URI, trying to serialize this will break.
# http://fan.zib.de/aot29/topic__118999.owl#4: translat, speech, neural does not look like a valid URI, trying to serialize this will break.
# http://fan.zib.de/aot29/topic__118999.owl#4.8: translat, nmt, machin does not look like a valid URI, trying to serialize this will break.
# http://fan.zib.de/aot29/topic__118999.owl#4: translat, speech, neural does not look like a valid URI, trying to serialize this will break.
# http://fan.zib.de/aot29/topic__118999.owl#4.7: languag, word, resourc does not look like a valid URI, trying to serialize this will break.
# http://fan.zib.de/aot29/topic__118999.owl#4: translat, speech, neural does not look like a valid URI, trying to serialize this will break.
# http://fan.zib.de/aot29/topic__118999.owl#4.4: translat, machin, english does not look like a valid URI, trying to serialize this will break.
# http://fan.zib.de/aot29/topic__118999.owl#4: translat, speech, neural does not look like a valid URI, trying to serialize this will break.
# http://fan.zib.de/aot29/topic__118999.owl#4.6: asr, error, recognit does not look like a valid URI, trying to serialize this will break.
# http://fan.zib.de/aot29/topic__118999.owl#4: translat, speech, neural does not look like a valid URI, trying to serialize this will break.
# http://fan.zib.de/aot29/topic__118999.owl#5: train, task, perform does not look like a valid URI, trying to serialize this will break.
# http://fan.zib.de/aot29/topic__118999.owl#5.0: distil, larg, comput does not look like a valid URI, trying to serialize this will break.
# http://fan.zib.de/aot29/topic__118999.owl#5: train, task, perform does not look like a valid URI, trying to serialize this will break.
# http://fan.zib.de/aot29/topic__118999.owl#5.1: tune, fine, data does not look like a valid URI, trying to serialize this will break.
# http://fan.zib.de/aot29/topic__118999.owl#5: train, task, perform does not look like a valid URI, trying to serialize this will break.
# http://fan.zib.de/aot29/topic__118999.owl#5.2: attent, transform, layer does not look like a valid URI, trying to serialize this will break.
# http://fan.zib.de/aot29/topic__118999.owl#5: train, task, perform does not look like a valid URI, trying to serialize this will break.
# http://fan.zib.de/aot29/topic__118999.owl#5.3: pre, bert, learn does not look like a valid URI, trying to serialize this will break.
# http://fan.zib.de/aot29/topic__118999.owl#5: train, task, perform does not look like a valid URI, trying to serialize this will break.
# http://fan.zib.de/aot29/topic__118999.owl#5.4: transform, network, learn does not look like a valid URI, trying to serialize this will break.
# http://fan.zib.de/aot29/topic__118999.owl#5: train, task, perform does not look like a valid URI, trying to serialize this will break.
# http://fan.zib.de/aot29/topic__118999.owl#6: user, dialogu, convers does not look like a valid URI, trying to serialize this will break.
# http://fan.zib.de/aot29/topic__118999.owl#6.3: research, process, paper does not look like a valid URI, trying to serialize this will break.
# http://fan.zib.de/aot29/topic__118999.owl#6: user, dialogu, convers does not look like a valid URI, trying to serialize this will break.
# http://fan.zib.de/aot29/topic__118999.owl#6.9: health, social, mental does not look like a valid URI, trying to serialize this will break.
# http://fan.zib.de/aot29/topic__118999.owl#6: user, dialogu, convers does not look like a valid URI, trying to serialize this will break.
# http://fan.zib.de/aot29/topic__118999.owl#6.0: llm, polit, larg does not look like a valid URI, trying to serialize this will break.
# http://fan.zib.de/aot29/topic__118999.owl#6: user, dialogu, convers does not look like a valid URI, trying to serialize this will break.
# http://fan.zib.de/aot29/topic__118999.owl#6.8: speech, messag, sentenc does not look like a valid URI, trying to serialize this will break.
# http://fan.zib.de/aot29/topic__118999.owl#6: user, dialogu, convers does not look like a valid URI, trying to serialize this will break.
# http://fan.zib.de/aot29/topic__118999.owl#6.12: bia, gender, bias does not look like a valid URI, trying to serialize this will break.
# http://fan.zib.de/aot29/topic__118999.owl#6: user, dialogu, convers does not look like a valid URI, trying to serialize this will break.
# http://fan.zib.de/aot29/topic__118999.owl#6.1: dialogu, task, agent does not look like a valid URI, trying to serialize this will break.
# http://fan.zib.de/aot29/topic__118999.owl#6: user, dialogu, convers does not look like a valid URI, trying to serialize this will break.
# http://fan.zib.de/aot29/topic__118999.owl#6.4: convers, topic, respons does not look like a valid URI, trying to serialize this will break.
# http://fan.zib.de/aot29/topic__118999.owl#6: user, dialogu, convers does not look like a valid URI, trying to serialize this will break.
# http://fan.zib.de/aot29/topic__118999.owl#6.11: user, question, answer does not look like a valid URI, trying to serialize this will break.
# http://fan.zib.de/aot29/topic__118999.owl#6: user, dialogu, convers does not look like a valid URI, trying to serialize this will break.
# http://fan.zib.de/aot29/topic__118999.owl#6.10: emot, review, user does not look like a valid URI, trying to serialize this will break.
# http://fan.zib.de/aot29/topic__118999.owl#6: user, dialogu, convers does not look like a valid URI, trying to serialize this will break.
# http://fan.zib.de/aot29/topic__118999.owl#6.5: gener, respons, user does not look like a valid URI, trying to serialize this will break.
# http://fan.zib.de/aot29/topic__118999.owl#6: user, dialogu, convers does not look like a valid URI, trying to serialize this will break.
# http://fan.zib.de/aot29/topic__118999.owl#7: dataset, detect, text does not look like a valid URI, trying to serialize this will break.
# http://fan.zib.de/aot29/topic__118999.owl#7.0: claim, legal, fact does not look like a valid URI, trying to serialize this will break.
# http://fan.zib.de/aot29/topic__118999.owl#7: dataset, detect, text does not look like a valid URI, trying to serialize this will break.
# http://fan.zib.de/aot29/topic__118999.owl#7.1: corpu, english, resourc does not look like a valid URI, trying to serialize this will break.
# http://fan.zib.de/aot29/topic__118999.owl#7: dataset, detect, text does not look like a valid URI, trying to serialize this will break.
# http://fan.zib.de/aot29/topic__118999.owl#7.2: hate, detect, speech does not look like a valid URI, trying to serialize this will break.
# http://fan.zib.de/aot29/topic__118999.owl#7: dataset, detect, text does not look like a valid URI, trying to serialize this will break.
# http://fan.zib.de/aot29/topic__118999.owl#7.3: annot, dialect, analysi does not look like a valid URI, trying to serialize this will break.
# http://fan.zib.de/aot29/topic__118999.owl#7: dataset, detect, text does not look like a valid URI, trying to serialize this will break.
# http://fan.zib.de/aot29/topic__118999.owl#7.4: task, score, perform does not look like a valid URI, trying to serialize this will break.
# http://fan.zib.de/aot29/topic__118999.owl#7: dataset, detect, text does not look like a valid URI, trying to serialize this will break.
# http://fan.zib.de/aot29/topic__118999.owl#7.5: sentiment, social, tweet does not look like a valid URI, trying to serialize this will break.
# http://fan.zib.de/aot29/topic__118999.owl#7: dataset, detect, text does not look like a valid URI, trying to serialize this will break.
# http://fan.zib.de/aot29/topic__118999.owl#7.6: new, articl, fake does not look like a valid URI, trying to serialize this will break.
# http://fan.zib.de/aot29/topic__118999.owl#7: dataset, detect, text does not look like a valid URI, trying to serialize this will break.
# http://fan.zib.de/aot29/topic__118999.owl#7.7: dataset, research, data does not look like a valid URI, trying to serialize this will break.
# http://fan.zib.de/aot29/topic__118999.owl#7: dataset, detect, text does not look like a valid URI, trying to serialize this will break.
# <Graph identifier=N190dc49c21904086ab756b6a262f4b74 (<class 'rdflib.graph.Graph'>)>

# %%
class GraphViz():

    # elements that will be removed frpm the visualization
    filter_terms = ['word_probabilities', 'topic_id', 'domain', 'range', 'Thing', 'NamedIndividual', 'type', 'label']

    node_color = 'lightgray'
    label_font_color =  'gray'
    
    def __init__(self, g):
        # store the graph
        self.g = g
        # Create a NetworkX graph
        self.G = nx.DiGraph()
        # Extract and add triples to the NetworkX graph
        for subj, pred, obj in g:
            if self._filter_out(subj, pred, obj): continue    
            subj_label = self._parse_label(subj)
            pred_label = self._parse_label(pred)
            obj_label = self._parse_label(obj)
            
            self.G.add_edge(subj_label, obj_label, label=pred_label)

    def __str__(self):
        resp = ""
        for subj, pred, obj in g:
            if self._filter_out(subj, pred, obj): continue    
            subj_label = self._parse_label(subj)
            pred_label = self._parse_label(pred)
            obj_label = self._parse_label(obj)
            resp += (f"{subj_label}, {pred_label}, {obj_label}\n")
        return resp
        
    def draw(self):
        # Draw the graph
        #  ‘dot’, ‘twopi’, ‘fdp’, ‘sfdp’, ‘circo’, 'neato'
        pos = graphviz_layout(self.G, prog="neato")
        plt.figure(figsize=(12, 12))
        nx.draw(self.G, pos, with_labels=True, node_size=3000, node_color=self.node_color, font_size=10, font_weight="normal", arrows=True)
        
        # Draw edge labels
#        edge_labels = {(n1, n2): d['label'] for n1, n2, d in self.G.edges(data=True)}
        edge_labels = {(n1, n2): '' for n1, n2, d in self.G.edges(data=True)}
        nx.draw_networkx_edge_labels(self.G, pos, edge_labels=edge_labels, font_color=self.label_font_color)
    
    def _filter_out(self, subj, pred, obj):
        found = False
        for term in self.filter_terms:
            if (term in subj) or (term in pred) or (term in obj):
                found = True
                break
        return found

    def _parse_label(self, raw):
        raw = str(raw)
        resp = raw
        if '#' in raw:
            resp = raw.split('#')[1]
        return resp

# %%
g_viz = GraphViz(g)
g_viz.draw()
plt.show()
print(g_viz)
# Out:
# 6: user, dialogu, convers, has_parent, NLP
# 3: inform, entiti, extract, has_parent, NLP
# 0.1: semant, structur, process, has_parent, 0: word, embed, semant
# 4.4: translat, machin, english, has_parent, 4: translat, speech, neural
# 0: word, embed, semant, has_parent, NLP
# 6.1: dialogu, task, agent, has_parent, 6: user, dialogu, convers
# 3.0: entiti, inform, relat, has_parent, 3: inform, entiti, extract
# 6.4: convers, topic, respons, has_parent, 6: user, dialogu, convers
# 2.3: adversari, attack, exampl, has_parent, 2: data, train, learn
# 7.7: dataset, research, data, has_parent, 7: dataset, detect, text
# 6.3: research, process, paper, has_parent, 6: user, dialogu, convers
# 5.1: tune, fine, data, has_parent, 5: train, task, perform
# 4.6: asr, error, recognit, has_parent, 4: translat, speech, neural
# 2.0: cross, entiti, lingual, has_parent, 2: data, train, learn
# 1.6: question, answer, knowledg, has_parent, 1: gener, question, llm
# 7.6: new, articl, fake, has_parent, 7: dataset, detect, text
# 6.11: user, question, answer, has_parent, 6: user, dialogu, convers
# 7.1: corpu, english, resourc, has_parent, 7: dataset, detect, text
# 7.4: task, score, perform, has_parent, 7: dataset, detect, text
# 5.0: distil, larg, comput, has_parent, 5: train, task, perform
# 3.3: document, queri, summar, has_parent, 3: inform, entiti, extract
# 6.12: bia, gender, bias, has_parent, 6: user, dialogu, convers
# 7.5: sentiment, social, tweet, has_parent, 7: dataset, detect, text
# 2.1: resourc, translat, multilingu, has_parent, 2: data, train, learn
# 6.0: llm, polit, larg, has_parent, 6: user, dialogu, convers
# 6.8: speech, messag, sentenc, has_parent, 6: user, dialogu, convers
# 7.0: claim, legal, fact, has_parent, 7: dataset, detect, text
# 4.10: network, neural, layer, has_parent, 4: translat, speech, neural
# 4.0: speaker, voic, audio, has_parent, 4: translat, speech, neural
# 4.7: languag, word, resourc, has_parent, 4: translat, speech, neural
# 6.9: health, social, mental, has_parent, 6: user, dialogu, convers
# 1.1: code, learn, problem, has_parent, 1: gener, question, llm
# 4: translat, speech, neural, has_parent, NLP
# 3.6: event, aspect, extract, has_parent, 3: inform, entiti, extract
# 2.5: gener, distribut, predict, has_parent, 2: data, train, learn
# 1.5: imag, visual, caption, has_parent, 1: gener, question, llm
# 7.3: annot, dialect, analysi, has_parent, 7: dataset, detect, text
# 1.2: explan, human, predict, has_parent, 1: gener, question, llm
# 0.2: concept, topic, semant, has_parent, 0: word, embed, semant
# 4.9: end, neural, network, has_parent, 4: translat, speech, neural
# 1: gener, question, llm, has_parent, NLP
# 5.4: transform, network, learn, has_parent, 5: train, task, perform
# 7.2: hate, detect, speech, has_parent, 7: dataset, detect, text
# 0.0: word, embed, represent, has_parent, 0: word, embed, semant
# 5: train, task, perform, has_parent, NLP
# 1.4: evalu, metric, human, has_parent, 1: gener, question, llm
# 3.2: graph, text, inform, has_parent, 3: inform, entiti, extract
# 3.1: knowledg, graph, dialogu, has_parent, 3: inform, entiti, extract
# 3.9: network, neural, attent, has_parent, 3: inform, entiti, extract
# 7: dataset, detect, text, has_parent, NLP
# 6.5: gener, respons, user, has_parent, 6: user, dialogu, convers
# 3.4: clinic, medic, data, has_parent, 3: inform, entiti, extract
# 5.3: pre, bert, learn, has_parent, 5: train, task, perform
# 1.3: text, video, sentenc, has_parent, 1: gener, question, llm
# 6.10: emot, review, user, has_parent, 6: user, dialogu, convers
# 0.3: word, text, base, has_parent, 0: word, embed, semant
# 4.8: translat, nmt, machin, has_parent, 4: translat, speech, neural
# 2.2: text, style, transfer, has_parent, 2: data, train, learn
# 5.2: attent, transform, layer, has_parent, 5: train, task, perform
# 2: data, train, learn, has_parent, NLP
# 1.0: llm, larg, prompt, has_parent, 1: gener, question, llm
# 3.8: code, corefer, match, has_parent, 3: inform, entiti, extract
# 0.4: gener, base, pars, has_parent, 0: word, embed, semant
# 4.3: data, recognit, represent, has_parent, 4: translat, speech, neural
# 4.1: decod, sequenc, encod, has_parent, 4: translat, speech, neural
# 4.2: gener, text, tt, has_parent, 4: translat, speech, neural
# 3.7: relat, extract, report, has_parent, 3: inform, entiti, extract
# 2.6: shot, dataset, zero, has_parent, 2: data, train, learn
